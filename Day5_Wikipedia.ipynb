# %% [markdown]
# <a href="https://colab.research.google.com/github/jovial123keerthi-bit/Generative_AI/blob/main/Day5_Wikipedia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-huggingface wikipedia --q
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install langchain-community --q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 32.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 3.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

# %%
import os

# %%
os.environ['HF_Token']="hf_iaQENgErdxPuhDsieXrgRpURDlKYAswcSdw"

# %%
ChatHuggingFace(llm=HuggingFaceEndpoint(repo_id="deepseek-ai/DeepSeek-V4-Flash-0731"))
# Out:
# ChatHuggingFace(metadata={'lc_versions': {'langchain-core': '1.5.5', 'langchain': '1.3.15'}}, llm=HuggingFaceEndpoint(metadata={'lc_versions': {'langchain-core': '1.5.5', 'langchain': '1.3.15'}}, repo_id='deepseek-ai/DeepSeek-V4-Flash-0731', stop_sequences=[], server_kwargs={}, model_kwargs={}, model='deepseek-ai/DeepSeek-V4-Flash-0731', client=<InferenceClient(model='deepseek-ai/DeepSeek-V4-Flash-0731', timeout=120)>, async_client=<InferenceClient(model='deepseek-ai/DeepSeek-V4-Flash-0731', timeout=120)>), model_id='deepseek-ai/DeepSeek-V4-Flash-0731', temperature=0.8, top_p=0.95, max_tokens=512, model_kwargs={})

# %%
llm=ChatHuggingFace(llm=HuggingFaceEndpoint(repo_id="deepseek-ai/DeepSeek-V4-Flash-0731"))

# %%
from langchain_community.tools import WikipediaQueryRun

# %%
from langchain_community.utilities import WikipediaAPIWrapper

# %%
wrap = WikipediaAPIWrapper(top_k_results=1, doc_content_chars_max=100)

# %%
wiki = WikipediaQueryRun(api_wrapper=wrap)

# %%
wiki.invoke({"query": "Quantum computer"})
# Out:
# 'Page: Quantum computing\nSummary: A quantum computer is a computer that represents and processes info'

# %%
'Page: Quantum computing\nSummary: A quantum computer is a computer that represents and processes info'
# Out:
# 'Page: Quantum computing\nSummary: A quantum computer is a computer that represents and processes info'
